# %%
f = open('main.txt', 'r')
print(f)
# Out:
# <_io.TextIOWrapper name='main.txt' mode='r' encoding='cp1252'>

# %%
f = open('main.txt', 'r')
print(f.read)
# Out:
# <built-in method read of _io.TextIOWrapper object at 0x00CBCDB0>

# %%
f = open('main.txt', 'r')
print(f.readline())
# Out:
# This is a file used check read write functionality of open function in Python.

# %%
f = open('main.txt', 'r')
print(f.readline(10))
# Out:
# This is a

# %%
f = open('main.txt', 'r')
print(f.readline())
print(f.readline())
# Out:
# This is a file used check read write functionality of open function in Python.
#
# This is Second Line.

# %%
f = open('main.txt', 'r')
print(f.readline(), end="")
print(f.readline())
# Out:
# This is a file used check read write functionality of open function in Python.
# This is Second Line.

# %%
f1 = open('WriteFile', 'w')

# %%
f1.write("Some")
# Out:
# 4

# %%
f1.write(" people")
# Out:
# 7

# %%
f1.write(" have Laptop")
# Out:
# 12

# %%
f1 = open('WriteFile', 'a')
f1.write(" and some have Mobile.")
# Out:
# 22

# %% [markdown]
# # copy data from "main.txt" to "WriteFile"

# %%
f = open('main.txt', 'r')

f1 = open('WriteFile', 'w')

for data in f:
    f1.write(data)

# %%
# f2 = open('image.jpg', 'r')  #---this generate error----
f2 = open('image.jpg', 'rb')

for i in f2:
    print(i)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n'
# b'\x07\x07\x06\x08\x0c\n'
# b'\x0c\x0c\x0b\n'
# b'\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\xff\xdb\x00C\x01\x03\x04\x04\x05\x04\x05\t\x05\x05\t\x14\r\x0b\r\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\xff\xc0\x00\x11\x08\x04\xb0\x07\x80\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n'
# ...

# %%
img = open('image.jpg', 'rb')

img1 = open('MyPic.jpg', 'wb')

for i in img:
    img1.write(i)
